# %% [markdown]
# #Overview

# %% [markdown]
# The purpose of this notebook was to explore the Center for Research in Security Prices (CRSP) mutual fund dataset accessed through Wharton Research Data Services (WRDS) and select funds that were used in our portfolio.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np

#Enables viewing of large variables and dataframes when printed 
pd.options.display.max_colwidth = 200

# %% [markdown]
# ## Set Path to Data

# %%
filepath = 'PATH_TO_DATA'

# %% [markdown]
#  Helper Function to Print Dataframe Properties in their Entirety

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %% [markdown]
# # Dataset Exploratory Data Analysis

# %% [markdown]
# ## Year-end CRSP Mutual Fund Dataset EDA

# %%
#Read in CSV file
crsp_mf_since2016 = pd.read_csv(filepath + 'crsp_mutulfundsummary_since2016.csv', encoding='latin-1')

# %%
#Dataframe shape
crsp_mf_since2016.shape
# Out:
# (192911, 73)

# %%
#See first five entries
display(crsp_mf_since2016.head())
# Out:
#   summary_period2  crsp_fundno     caldt  nav_latest  nav_latest_dt  \
# 0              AQ          105  20161230       12.79       20161230
# 1              AQ          105  20171229       14.96       20171229
# 2              AQ          105  20181231       10.32       20181231
# 3              AQ          105  20191231       12.28       20191231
# 4              AQ          105  20201231       13.78       20201231
#
#    tna_latest  tna_latest_dt  yield  div_ytd  cap_gains_ytd  ...  \
# 0        26.5     20161230.0    NaN      NaN       0.138945  ...
# 1        29.6     20171229.0    NaN      NaN       1.157885  ...
# 2        21.2     20181231.0    NaN      NaN       2.626225  ...
# 3        26.6     20191231.0    NaN      NaN       1.154015  ...
# 4        34.7     20201231.0    NaN      NaN       1.922754  ...
#
#    accrual_fund  sales_restrict  wbrger_obj_cd  policy  lipper_class  \
# 0             N               N            NaN     NaN          GMLG
# 1             N               N            NaN     NaN          GMLG
# 2             N               N            NaN     NaN          GSME
# 3             N               N            NaN     NaN          GMLG
# 4             N               N            NaN     NaN          GMLG
#
#              lipper_class_name  lipper_obj_cd  lipper_obj_name  \
# 0      Global Multi-Cap Growth             GL     GLOBAL FUNDS
# 1      Global Multi-Cap Growth             GL     GLOBAL FUNDS
# 2  Global Small-/Mid-Cap Funds             GL     GLOBAL FUNDS
# 3  Global Multi-Cap Growth Fds             GL     GLOBAL FUNDS
# 4  Global Multi-Cap Growth Fds             GL     GLOBAL FUNDS
#
#    lipper_asset_cd  lipper_tax_cd
# 0               EQ        Taxable
# 1               EQ        Taxable
# 2               EQ        Taxable
# 3               EQ        Taxable
# 4               EQ        Taxable
#
# [5 rows x 73 columns]

# %%
#See available fields
display(crsp_mf_since2016.columns)
# Out:
# Index(['summary_period2', 'crsp_fundno', 'caldt', 'nav_latest',
#        'nav_latest_dt', 'tna_latest', 'tna_latest_dt', 'yield', 'div_ytd',
#        'cap_gains_ytd', 'nav_52w_h', 'nav_52w_h_dt', 'nav_52w_l',
#        'nav_52w_l_dt', 'unrealized_app_dep', 'unrealized_app_dt', 'asset_dt',
#        'per_com', 'per_pref', 'per_conv', 'per_corp', 'per_muni', 'per_govt',
#        'per_oth', 'per_cash', 'per_bond', 'per_abs', 'per_mbs', 'per_eq_oth',
#        'per_fi_oth', 'maturity', 'maturity_dt', 'cusip8', 'crsp_portno',
#        'crsp_cl_grp', 'fund_name', 'ticker', 'ncusip', 'mgmt_name', 'mgmt_cd',
#        'mgr_name', 'mgr_dt', 'adv_name', 'open_to_inv', 'retail_fund',
#        'inst_fund', 'm_fund', 'index_fund_flag', 'vau_fund', 'et_flag',
#        'delist_cd', 'first_offer_dt', 'end_dt', 'dead_flag', 'merge_fundno',
#        'actual_12b1', 'max_12b1', 'mgmt_fee', 'exp_ratio', 'turn_ratio',
#        'fiscal_yearend', 'crsp_obj_cd', 'si_obj_cd', 'accrual_fund',
#        'sales_restrict', 'wbrger_obj_cd', 'policy', 'lipper_class',
#        'lipper_class_name', 'lipper_obj_cd', 'lipper_obj_name',
#        'lipper_asset_cd', 'lipper_tax_cd'],
#       dtype='object')

# %%
#Display fields that have non-zero N/A counts
null_counts = crsp_mf_since2016.isna().sum()
print_full(null_counts[null_counts > 0])
# Out:
# tna_latest              6499
# tna_latest_dt           4830
# yield                  48378
# div_ytd                47634
# cap_gains_ytd         103628
# unrealized_app_dep    192911
# unrealized_app_dt     192911
# asset_dt                8505
# per_com                 8505
# per_pref                8505
# per_conv                8505
# per_corp                8505
# per_muni                8505
# per_govt                8505
# per_oth                 8505
# per_cash                8505
# per_bond                8505
# per_abs                 8505
# per_mbs                 8505
# per_eq_oth              8505
# per_fi_oth              8505
# maturity               83835
# maturity_dt            82956
# cusip8                  2135
# crsp_portno             8058
# crsp_cl_grp             1035
# fund_name               1009
# ticker                 23130
# ncusip                  2135
# mgmt_name               1104
# mgmt_cd                24430
# mgr_name               24441
# mgr_dt                 72172
# adv_name                1010
# open_to_inv             1009
# retail_fund             1009
# inst_fund               1009
# m_fund                 23604
# index_fund_flag       171422
# vau_fund                1009
# et_flag               179256
# delist_cd             186154
# first_offer_dt          1009
# end_dt                  1009
# dead_flag               1009
# merge_fundno          181577
# actual_12b1           134481
# max_12b1              129150
# mgmt_fee               63913
# exp_ratio              65031
# turn_ratio             69638
# fiscal_yearend         63913
# crsp_obj_cd              265
# si_obj_cd             192911
# accrual_fund             265
# sales_restrict           265
# wbrger_obj_cd         192911
# policy                192911
# lipper_class             265
# lipper_class_name        265
# lipper_obj_cd            265
# lipper_obj_name          708
# lipper_asset_cd          708
# lipper_tax_cd            708
# dtype: int64

# %%
#Print first entry
print_full(crsp_mf_since2016.iloc[0])
# Out:
# summary_period2                                                                      AQ
# crsp_fundno                                                                         105
# caldt                                                                          20161230
# nav_latest                                                                        12.79
# nav_latest_dt                                                                  20161230
# tna_latest                                                                         26.5
# tna_latest_dt                                                                20161230.0
# yield                                                                               NaN
# div_ytd                                                                             NaN
# cap_gains_ytd                                                                  0.138945
# nav_52w_h                                                                          13.3
# nav_52w_h_dt                                                                   20160907
# nav_52w_l                                                                         10.79
# nav_52w_l_dt                                                                   20160211
# unrealized_app_dep                                                                  NaN
# unrealized_app_dt                                                                   NaN
# asset_dt                                                                     20161031.0
# per_com                                                                           79.76
# per_pref                                                                            0.3
# per_conv                                                                            0.0
# per_corp                                                                           0.21
# per_muni                                                                            0.0
# per_govt                                                                           1.16
# per_oth                                                                           -0.29
# per_cash                                                                           0.73
# per_bond                                                                            0.0
# per_abs                                                                             0.0
# per_mbs                                                                             0.0
# per_eq_oth                                                                        17.48
# per_fi_oth                                                                         0.62
# maturity                                                                            2.0
# maturity_dt                                                                  20160131.0
# cusip8                                                                          2883710
# crsp_portno                                                                   1022431.0
# crsp_cl_grp                                                                   2000026.0
# fund_name             American Pension Investors Trust: API Growth Fund; Class L Shares
# ticker                                                                            APITX
# ncusip                                                                         28837102
# mgmt_name                                          Yorktown Mgmt & Research Company Inc
# mgmt_cd                                                                             API
# mgr_name                                                                   Team Managed
# mgr_dt                                                                              NaN
# adv_name                                           Yorktown Mgmt & Research Company Inc
# open_to_inv                                                                           Y
# retail_fund                                                                           Y
# inst_fund                                                                             N
# m_fund                                                                                N
# index_fund_flag                                                                     NaN
# vau_fund                                                                              N
# et_flag                                                                             NaN
# delist_cd                                                                           NaN
# first_offer_dt                                                               19850614.0
# end_dt                                                                       20211231.0
# dead_flag                                                                             N
# merge_fundno                                                                        NaN
# actual_12b1                                                                      0.0075
# max_12b1                                                                           0.01
# mgmt_fee                                                                            1.0
# exp_ratio                                                                        0.0244
# turn_ratio                                                                         0.37
# fiscal_yearend                                                               20170131.0
# crsp_obj_cd                                                                          EF
# si_obj_cd                                                                           NaN
# accrual_fund                                                                          N
# sales_restrict                                                                        N
# wbrger_obj_cd                                                                       NaN
# policy                                                                              NaN
# lipper_class                                                                       GMLG
# lipper_class_name                                               Global Multi-Cap Growth
# lipper_obj_cd                                                                        GL
# lipper_obj_name                                                            GLOBAL FUNDS
# lipper_asset_cd                                                                      EQ
# lipper_tax_cd                                                                   Taxable
# Name: 0, dtype: object

# %%
#See available dates
display(crsp_mf_since2016['caldt'].unique())
# Out:
# array([20161230, 20171229, 20181231, 20191231, 20201231, 20211231])

# %%
#See Lipper Asset Codes
#EQ - Equity Funds
#TX - Taxable Fixed Income Funds
#MB - Tax Free Fixed Income Funds
crsp_mf_since2016['lipper_asset_cd'].unique()
# Out:
# array(['EQ', 'TX', 'MB', nan], dtype=object)

# %%
#Number of funds per Lipper Asset Codes across all available dates
#There are far more equity-centric funds than fixed income funds
crsp_mf_since2016['lipper_asset_cd'].value_counts(dropna=False)
# Out:
# EQ     140083
# TX      39746
# MB      12374
# NaN       708
# Name: lipper_asset_cd, dtype: int64

# %% [markdown]
# ## Selecting an Equity Fund

# %%
#See Lipper Classification Names for Equity Funds
#The S&P 500 Index Funds classification was selected
display(crsp_mf_since2016[crsp_mf_since2016['lipper_asset_cd'] == 'EQ']['lipper_class_name'].unique())
# Out:
# array(['Global Multi-Cap Growth', 'Global Small-/Mid-Cap Funds',
#        'Global Multi-Cap Growth Fds', 'Small-Cap Core Funds',
#        'Equity Income Funds', 'Small-Cap Growth Funds',
#        'Mid-Cap Core Funds', 'Mid-Cap Value Funds',
#        'Mixed-Asset Target Alloc Growth Funds', 'Large-Cap Growth Funds',
#        'Mixed-Asset Target Alloc Moderate Funds',
#        'Mixed-Asset Trgt Alloc Mod Fds', 'Mixed-Asset Target 2020 Funds',
#        'Large-Cap Core Funds', 'Multi-Cap Value Funds',
#        'Multi-Cap Growth Funds', 'Global Real Estate Funds',
#        'Global Large-Cap Core', 'Global Multi-Cap Value Fds',
#        'Global Multi-Cap Core Fds', 'International Small/Mid-Cap Core',
#        'International Small/Mid-Cap Growth',
#        'International Sm/Md-Cp Gro Fds',
#        'Mixed-Asset Target Alloc Consv Funds',
#        'Mixed-Asset Trgt Alloc Con Fds', 'International Multi-Cap Core',
#        'International Multi-Cp Core Fds', 'Global Equity Income Funds',
#        'International Equity Income Fds',
#        'Mixed-Asset Trgt Alloc Gro Fds',
#        'Global Health/Biotechnology Funds',
#        'Global Health/Biotechnology Fds', 'China Region Funds',
#        'Emerging Markets Funds', 'Multi-Cap Core Funds',
#        'Real Estate Funds', 'Natural Resources Funds',
#        'Science & Technology Funds', 'Precious Metals Equity Funds',
#        'Flexible Portfolio Funds', 'Small-Cap Value Funds',
#        'Mixed-Asset Target Today Funds', 'Alternative Global Macro Funds',
#        'International Large-Cap Value', 'International Large-Cap Core',
#        'International Large-Cp Core Fds', 'International Multi-Cap Value',
#        'International Multi-Cp Val Fds', 'International Large-Cp Val Fds',
#        'Large-Cap Value Funds', 'International Multi-Cap Growth',
#        'Specialty/Miscellaneous Funds', 'Mid-Cap Growth Funds',
#        'European Region Funds', 'International Large-Cap Growth',
#        'International Large-Cp Gro Fds', 'Pacific Ex Japan Funds',
#        'Mixed-Asset Target 2050 Funds', 'Mixed-Asset Target 2040 Funds',
#        'Mixed-Asset Target 2030 Funds', 'International Multi-Cp Gro Fds',
#        'Health/Biotechnology Funds', 'S&P 500 Index Funds',
#        'Mixed-Asset Target Alloc Agg Gro Funds',
#        'Mixed-Asset Trgt All Agg Gr Fds',
#        'Global Science/Technology Funds', 'Global Science/Technology Fds',
#        'Global Natural Resources Funds', 'Financial Services Funds',
#        'International Real Estate Funds', 'Mixed-Asset Target 2025 Funds',
#        'Mixed-Asset Target 2045 Funds', 'Mixed-Asset Target 2035 Funds',
#        'Alternative Equity Market Neutral Funds',
#        'Alternative Eq Mrkt Neutral Fds', 'Utility Funds',
#        'Global Large-Cap Growth Fds', 'Mixed-Asset Target 2010 Funds',
#        'Mixed-Asset Target 2015 Funds', 'Global Multi-Cap Core',
#        'Global Multi-Cap Value', 'International Sm/Md-Cp Core Fds',
#        'Alternative Event Driven Funds', 'Global Large-Cap Value Fds',
#        'International Equity Income Funds', 'Latin American Funds',
#        'Global Large-Cap Growth', 'Global Large-Cap Core Fds',
#        'Pacific Region Funds', 'Alternative Long/Short Equity Funds',
#        'Options Arbitrage/Opt Strat Fds',
#        'Alternative Long/Short Eqty Fds', 'Convertible Securities Funds',
#        'S&P Midcap 400 Index Funds', 'Global Infrastructure Funds',
#        'Japanese Funds', 'Specialty Diversified Equity Funds',
#        'Global Large-Cap Value', 'Commodities General Funds',
#        'International Small/Mid-Cap Value',
#        'International Sm/Md-Cp Val Fds', 'Telecommunication Funds',
#        'Real Return Funds', 'Equity Leverage Funds',
#        'Dedicated Short Bias Funds', 'India Region Funds',
#        'Alternative Multi-Strategy Funds', 'Absolute Return Funds',
#        'Industrials Funds', 'Consumer Services Funds',
#        'Basic Materials Funds', 'Consumer Goods Funds',
#        'Alternative Energy Funds', 'Global Financial Services Funds',
#        'Retirement Income Funds', 'Alternative Active Extension Funds',
#        'Alternative Act Extension Fds', 'S&P 500 Index Objective Funds',
#        'Commodities Precious Metals Funds', 'Commodities Prec Metals Fds',
#        'Commodities Energy Funds', 'Commodities Agriculture Funds',
#        'Commodities Base Metals Funds', 'Commodities Base Metals Fds',
#        'Mixed-Asset Target 2055+ Funds', 'Mixed-Asset Target 2055 Funds',
#        'Alternative Managed Futures Funds',
#        'Alternative Managed Futures Fds', 'Commodities Specialty Funds',
#        'Frontier Markets Funds', 'Energy MLP Funds',
#        'Emerging Mrkts Mixed-Asset Fds', 'Mixed-Asset Target 2060 Funds',
#        'Mixed-Asset Target 2060+ Funds'], dtype=object)

# %% [markdown]
# Here we select the top 10 largest funds as the end of 2020 within the 'S&P 500 Index Funds' Lipper Asset Classification and launched before 2010, giving us at least 10 years worth of data. We select the largest fund the **BlackRock Funds III: iShares S&P 500 Index Fund; Class K Shares**

# %%
crsp_eq_sp500_2020 = crsp_mf_since2016[(crsp_mf_since2016['lipper_class_name'] == 'S&P 500 Index Funds') & 
                                        (crsp_mf_since2016['caldt'] == 20201231) &
                                        (crsp_mf_since2016['first_offer_dt'] <= 20100000)].sort_values(by='nav_latest', ascending=False).reset_index()

print_full(crsp_eq_sp500_2020[['fund_name', 'nav_latest', 'crsp_fundno']].head(10))
# Out:
#                                                                                          fund_name  \
# 0                                  BlackRock Funds III: iShares S&P 500 Index Fund; Class K Shares
# 1                                                          iShares Trust: iShares Core S&P 500 ETF
# 2                                                                           SPDR S&P 500 ETF Trust
# 3                   Variable Insurance Products Fund II: Index 500 Portfolio; Initial Class Shares
# 4                   Variable Insurance Products Fund II: Index 500 Portfolio; Service Class Shares
# 5                 Variable Insurance Products Fund II: Index 500 Portfolio; Service Class 2 Shares
# 6                                   Vanguard Index Funds: Vanguard 500 Index Fund; Investor Shares
# 7                                    Vanguard Index Funds: Vanguard 500 Index Fund; Admiral Shares
# 8  Vanguard Institutional Index Fund: Vanguard Institutional Index Fund; Institutional Plus Shares
# 9       Vanguard Institutional Index Fund: Vanguard Institutional Index Fund; Institutional Shares
#
#    nav_latest  crsp_fundno
# 0    444.2800         5887
# 1    375.5400        16416
# 2    374.1758        27635
# 3    371.5900        38413
# 4    370.1200        39505
# 5    366.7300        39332
# 6    346.6000        31432
# 7    346.5700        31461
# 8    331.4800        31332
# 9    331.4700        31331

# %%
crsp_eq_sp500_2020.iloc[0][['fund_name', 'nav_latest', 'crsp_fundno']]
# Out:
# fund_name      BlackRock Funds III: iShares S&P 500 Index Fund; Class K Shares
# nav_latest                                                              444.28
# crsp_fundno                                                               5887
# Name: 0, dtype: object

# %% [markdown]
# ## Selecting a Fixed Income Fund

# %%
#See Lipper Classification Names for Equity Funds
#No particular category was selected
display(crsp_mf_since2016[crsp_mf_since2016['lipper_asset_cd'] != 'EQ']['lipper_class_name'].unique())
# Out:
# array(['Core Bond Funds', 'Loan Participation Funds',
#        'International Income Funds', 'Global Income Funds',
#        'Inflation Protected Bond Funds',
#        'Intermediate U.S. Government Funds',
#        'Alternative Credit Focus Funds',
#        'Short Investment Grade Debt Funds', 'High Yield Funds',
#        'U.S. Government Money Market Funds',
#        'Instl U.S. Government Money Market Funds', 'Money Market Funds',
#        'Specialty Fixed Income Funds', 'Corporate Debt Funds BBB-Rated',
#        'U.S. Mortgage Funds', 'Short U.S. Government Funds',
#        'Ultra-Short Obligations Funds',
#        'Short-Intmdt Investment Grade Debt Funds',
#        'Global High Yield Funds', 'Absolute Return Bond Funds',
#        'Core Plus Bond Funds', 'General U.S. Treasury Funds',
#        'Short U.S. Treasury Funds', 'GNMA Funds',
#        'U.S. Treasury Money Market Funds',
#        'General U.S. Government Funds',
#        'Instl U.S. Treasury Money Market Funds', 'Flexible Income Funds',
#        'Instl Money Market Funds', 'Corporate Debt Funds A Rated',
#        'General Bond Funds', 'Short-Intermediate U.S. Government Funds',
#        'Multi-Sector Income Funds',
#        'Alternative Currency Strategies Funds',
#        'Emerging Mrkts Hard Currency Debt Funds',
#        'Intermediate Investment Grade Debt Funds',
#        'Short High Yield Funds',
#        'Emerging Markets Local Currency Debt Fds'], dtype=object)

# %% [markdown]
# Here we select the top 10 largest funds as the end of 2020 that are not an equity fund and launched before 2010, giving us at least 10 years worth of data. We select another BlackRock fund that tracks treasury bonds **iShares Trust: iShares 7-10 Year Treasury Bond ETF**

# %%
crsp_mf_tx_bond_2021 = crsp_mf_since2016[(crsp_mf_since2016['lipper_asset_cd'] != 'EQ') & 
                                        (crsp_mf_since2016['caldt'] == 20201231) &
                                        (crsp_mf_since2016['first_offer_dt'] <= 20120000)].sort_values(by='nav_latest', ascending=False).reset_index()
print_full(crsp_mf_tx_bond_2021[['fund_name', 'nav_latest', 'crsp_fundno']].head(15))
# Out:
#                                                                                 fund_name  \
# 0      PIMCO ETF Trust: PIMCO 25+ Year Zero Coupon US Treasury Index Exchange-Traded Fund
# 1                                     iShares Trust: iShares 10-20 Year Treasury Bond ETF
# 2                                       iShares Trust: iShares 20+ Year Treasury Bond ETF
# 3        Vanguard World Funds: Vanguard Extended Duration Treasury Index Fund; ETF Shares
# 4                      iShares Trust: iShares iBoxx $ Investment Grade Corporate Bond ETF
# 5                                       iShares Trust: iShares 3-7 Year Treasury Bond ETF
# 6                                     Invesco CurrencyShares British Pound Sterling Trust
# 7                                                    iShares Trust: iShares TIPS Bond ETF
# 8                                       iShares Trust: iShares Government/Credit Bond ETF
# 9                            Rydex Series Funds: High Yield Strategy Fund; Class A Shares
# 10                           Rydex Series Funds: High Yield Strategy Fund; Class H Shares
# 11                                     iShares Trust: iShares 7-10 Year Treasury Bond ETF
# 12                                                 iShares Trust: iShares Agency Bond ETF
# 13  Rydex Series Funds: Inverse Government Long Bond Strategy Fund; Investor Class Shares
# 14                                      iShares Trust: iShares Core US Aggregate Bond ETF
#
#     nav_latest  crsp_fundno
# 0     163.3899        47421
# 1     159.2800        16489
# 2     157.8900        16430
# 3     152.3000        35840
# 4     137.8900        16419
# 5     132.9500        16490
# 6     132.0854        43522
# 7     127.5900        16413
# 8     125.6900        16483
# 9     123.3600        27450
# 10    123.2800        27446
# 11    119.9500        16431
# 12    119.4800        43396
# 13    118.3900        27326
# 14    118.1300        16417

# %%
crsp_mf_tx_bond_2021.iloc[11][['fund_name', 'nav_latest', 'crsp_fundno']]
# Out:
# fund_name      iShares Trust: iShares 7-10 Year Treasury Bond ETF
# nav_latest                                                 119.95
# crsp_fundno                                                 16431
# Name: 11, dtype: object

# %% [markdown]
# #Extracting Daily Returns

# %% [markdown]
# From here we go to WRDS and access daily returns by fund code: 5887, 16431.
#
# Following the link below you will be able to select query the daily returns.
#
# Data between 2010-2012 was extracted in a CSV format with dates formatted to MMDDYY10.
#
# A WRDS account and access is required to access the platform.

# %% [markdown]
# https://wrds-www.wharton.upenn.edu/pages/get-data/center-research-security-prices-crsp/quarterly-update/mutual-funds/daily-returns/
